# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ##creating a dataframe

# %%
data = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 34, 56, 37],
    'Salary': [65000, 70000, 62000, 85000],
    'City': ['kol', 'del', 'che', 'ban'],
}
pd.DataFrame(data)
# Out:
#     Name  Age  Salary City
# 0   John   28   65000  kol
# 1   Anna   34   70000  del
# 2  Peter   56   62000  che
# 3  Linda   37   85000  ban

# %%
data_list = [
    ['jogn', 28, 'del', 65000],
    ['anna', 34, 'kol', 70000],
    ['peter', 29, 'che', 85000],
    ['linda', 45, 'ban', 62000]
]
df2 = pd.DataFrame(data_list)
columns = ["name", "age", "city", "salary"]
df2 = pd.DataFrame(data_list, columns= columns)
df2
# Out:
#     name  age city  salary
# 0   jogn   28  del   65000
# 1   anna   34  kol   70000
# 2  peter   29  che   85000
# 3  linda   45  ban   62000

# %%
df2[['name', 'city']]
# Out:
#     name city
# 0   jogn  del
# 1   anna  kol
# 2  peter  che
# 3  linda  ban

# %%
df2["designation"] = ['doctor', 'eng', 'texaher', 'painter']
df2
# Out:
#     name  age city  salary designation
# 0   jogn   28  del   65000      doctor
# 1   anna   34  kol   70000         eng
# 2  peter   29  che   85000     texaher
# 3  linda   45  ban   62000     painter

# %% [markdown]
# removing col

# %%
df2.drop(0, axis=0)
# Out:
#     name  age city  salary designation
# 1   anna   34  kol   70000         eng
# 2  peter   29  che   85000     texaher
# 3  linda   45  ban   62000     painter

# %% [markdown]
# selecting rows

# %%
df2.loc[[0,1]]
# Out:
#    name  age city  salary designation
# 0  jogn   28  del   65000      doctor
# 1  anna   34  kol   70000         eng

# %%
df2.iloc[3]
# Out:
# name             linda
# age                 45
# city               ban
# salary           62000
# designation    painter
# Name: 3, dtype: object

# %%
df2.loc[[0,1][['city', 'salary']]]
# Out:
# <>:1: SyntaxWarning: list indices must be integers or slices, not list; perhaps you missed a comma?
# <>:1: SyntaxWarning: list indices must be integers or slices, not list; perhaps you missed a comma?
# C:\Users\KIIT0001\AppData\Local\Temp\ipykernel_27344\2492170591.py:1: SyntaxWarning: list indices must be integers or slices, not list; perhaps you missed a comma?
#   df2.loc[[0,1][['city', 'salary']]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df2.loc[[0,1][['city', 'salary']]]
#
# TypeError: list indices must be integers or slices, not list
