# %%
import pandas as pd
import numpy as np

# %%
np.random.seed(42)

# %%
fastball_seed = np.random.randint(90, 106, size=500)

# %%
tommy_john = np.where(fastball_seed>96, np.random.choice([0,1], size=500, p=[0.3, 0.7]), 0)

# %%
d = {'fastball_seed': fastball_seed, 'tommy_john': tommy_john}

# %%
df = pd.DataFrame(data=d)

# %%
df
# Out:
#      fastball_seed  tommy_john
# 0               96           0
# 1               93           0
# 2              102           1
# 3              104           1
# 4              100           0
# ..             ...         ...
# 495            104           1
# 496             92           0
# 497            101           1
# 498             90           0
# 499             93           0
#
# [500 rows x 2 columns]
